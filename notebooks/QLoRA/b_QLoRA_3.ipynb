# %%
import os
import torch
import warnings
from datasets import load_dataset
from dotenv import load_dotenv
from transformers import (
    AutoModelForCausalLM, AutoTokenizer, TrainingArguments, Trainer, 
    DataCollatorForLanguageModeling, BitsAndBytesConfig
)
from peft import prepare_model_for_kbit_training, LoraConfig, get_peft_model, PeftModel
from tqdm import tqdm

# %%
# Suppress Warnings
warnings.filterwarnings("ignore")

# Load Environment Variables
env_path = "/media/volume/LegalEase/Repos/CPSC5830-Team1/.env"
load_dotenv(env_path)
HF_READ_TOKEN = os.getenv("BENS_HUGGING_FACE_READ_TOKEN")
HF_WRITE_TOKEN = os.getenv("BENS_HUGGING_FACE_WRITE_TOKEN")
print(f"Read Token: {HF_READ_TOKEN}")
print(f"Write Token: {HF_WRITE_TOKEN}")
# Out:
# Read Token: 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
# Write Token: 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

# %%
# Device Setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.empty_cache()
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Load Mistral 7B Model & Tokenizer
model_name = "mistralai/Mistral-7B-Instruct-v0.2"

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,  
    bnb_4bit_use_double_quant=True,  
    bnb_4bit_quant_type="nf4",  
    bnb_4bit_compute_dtype=torch.bfloat16  
)

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_name, 
    quantization_config=bnb_config,
    device_map="auto",
    token=HF_READ_TOKEN,
    cache_dir="/media/volume/LegalEaseMaxim/cache"
)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# Enable Gradient Checkpointing
model.gradient_checkpointing_enable()
model = prepare_model_for_kbit_training(model)

# %%
# Load Tokenizer & Set Padding
tokenizer = AutoTokenizer.from_pretrained(model_name, cache_dir="/media/volume/LegalEaseMaxim/cache")
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"

# %%
# Load Dataset
dataset_path = {"train": "my_dataset1.jsonl"}
data = load_dataset("json", data_files=dataset_path)

# %%
split_data = data["train"].train_test_split(test_size=0.1)
print(f"Training Data: {len(split_data['train'])}")
print(f"Validation Data: {len(split_data['test'])}")
# Out:
# Training Data: 558
# Validation Data: 62

# %%
def format_prompt(example):
    messages = example["messages"]
    formatted_text = ""
    for msg in messages:
        role = msg["role"]
        content = msg["content"]
        if role == "system":
            formatted_text += f"[SYSTEM] {content} [/SYSTEM]\n"
        elif role == "user":
            formatted_text += f"[INST] {content} [/INST]\n"
        elif role == "assistant":
            formatted_text += f"{content}\n"
    return {"formatted_text": formatted_text}

# %%
formatted_data = split_data.map(format_prompt).remove_columns(["messages"])
# Out:
# Map:   0%|          | 0/558 [00:00<?, ? examples/s]
# Map:   0%|          | 0/62 [00:00<?, ? examples/s]

# %%
# Tokenization Function
def tokenize_function(examples):
    return tokenizer(
        examples["formatted_text"], 
        truncation=True, 
        padding="max_length", 
        max_length=1024, 
        add_special_tokens=True
    )

# %%
tokenized_data = formatted_data.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/558 [00:00<?, ? examples/s]
# Map:   0%|          | 0/62 [00:00<?, ? examples/s]

# %%
# LoRA Configuration
config = LoraConfig(
    r=16,  
    lora_alpha=32,  
    target_modules=["q_proj", "v_proj", "k_proj", "o_proj"], 
    lora_dropout=0.1,  
    bias="none",  
    task_type="CAUSAL_LM"
)

# %%
model = get_peft_model(model, config)

# %%
# Data Collator
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)

# %%
# Training Arguments
training_args = TrainingArguments(
    output_dir="/media/volume/LegalEaseMaxim/output",
    learning_rate=2e-4,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=2,
    num_train_epochs=5,
    weight_decay=0.01,
    logging_strategy="epoch",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    gradient_accumulation_steps=4,
    warmup_steps=30,
    fp16=True,  
    optim="adamw_bnb_8bit"
)

# %%
# Trainer Setup
trainer = Trainer(
    model=model,
    train_dataset=tokenized_data["train"],
    eval_dataset=tokenized_data["test"],
    args=training_args,
    data_collator=data_collator
)
# Out:
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.

# %%
# Train Model
model.config.use_cache = False  
trainer.train()
model.config.use_cache = True
# Out:
#     <div>
#
#       <progress value='175' max='175' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [175/175 21:34, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.149200</td>
#       <td>0.678636</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.616000</td>
#       <td>0.625532</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.493500</td>
#       <td>0.613867</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.384400</td>
#       <td>0.636441</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.305900</td>
#       <td>0.675321</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
if isinstance(model, PeftModel):
    model = model.merge_and_unload()
    print("LoRA merged successfully!")
else:
    print("Model is not a PEFT model, skipping merge.")
# Out:
# LoRA merged successfully!

# %%
# Save Model & Tokenizer
model.save_pretrained("./business_llm")
tokenizer.save_pretrained("./business_llm")
model.cpu()
torch.cuda.empty_cache()

# %%
# Push to Hugging Face Hub
PUBLISH_TO_HUB = True
if PUBLISH_TO_HUB:
    repo_name = "XCIT3D247/LegalEaseV2"
    model.push_to_hub(repo_name, token=HF_WRITE_TOKEN)
    tokenizer.push_to_hub(repo_name, token=HF_WRITE_TOKEN)
    print(f"Model uploaded to: https://huggingface.co/{repo_name}")
# Out:
# model.safetensors:   0%|          | 0.00/4.65G [00:00<?, ?B/s]
# No files have been modified since last commit. Skipping to prevent empty commit.
# Model uploaded to: https://huggingface.co/XCIT3D247/LegalEaseV2

# %%
# Load Model for Inference
tokenizer = AutoTokenizer.from_pretrained(repo_name)
model = AutoModelForCausalLM.from_pretrained(repo_name, torch_dtype=torch.bfloat16, device_map="auto")
model = PeftModel.from_pretrained(model, repo_name)
# Out:
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Some parameters are on the meta device because they were offloaded to the cpu.
# Some parameters are on the meta device because they were offloaded to the cpu.
# Some parameters are on the meta device because they were offloaded to the cpu.

# %%
# Generate Responses
def generate_response(prompt, max_length=1028):
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    with torch.no_grad():
        output = model.generate(**inputs, max_length=max_length, pad_token_id=tokenizer.eos_token_id)
    return tokenizer.decode(output[0], skip_special_tokens=True)

# %%
# Test the Model
test_questions = [
    "What type of business entity should I choose for a tech startup?",
    "What are the tax implications of forming an LLC?",
    "How does Delaware compare to Washington for incorporating a business?"
]

# %%
for question in test_questions:
    print(f"Q: {question}")
    print(f"A: {generate_response(question)}\n")
# Out:
# Q: What type of business entity should I choose for a tech startup?
# A: What type of business entity should I choose for a tech startup?
#
# The choice of business entity for a tech startup depends on several factors, including your goals, liability concerns, tax implications, and regulatory requirements. Here's a breakdown of the most common options:
#
# 1. **Sole Proprietorship:** This is the simplest structure, but it offers the least protection. You are personally liable for all business debts and obligations. It's best for very small, low-risk startups.
#
# 2. **Partnership:** If you're starting with one or more co-founders, a partnership might be suitable. You'll need to define the roles and responsibilities of each partner and address issues of profit and loss sharing.  Partnerships can be general (unlimited liability) or limited (limited liability).
#
# 3. **Limited Liability Company (LLC):** This is a popular choice for many startups. It offers limited liability protection, meaning your personal assets are generally protected from business debts and lawsuits.  LLCs are relatively easy to set up and manage, and they offer flexibility in taxation (you can choose to be taxed as a sole proprietorship, partnership, or corporation).
#
# 4. **Corporation (S Corp or C Corp):** Corporations offer the strongest liability protection, separating your personal assets from business liabilities.  However, they are more complex and expensive to set up and maintain.  S Corps are generally preferred for smaller businesses because they avoid double taxation (profits are taxed only once, at the individual level). C Corps are more suitable for larger, more established companies.
#
# **Factors to Consider:**
#
# * **Liability Protection:**  This is the primary reason to choose a more complex business structure.  If you anticipate significant risk (e.g., dealing with intellectual property, high-value contracts, or significant investments), a corporation or LLC is advisable.
#
# * **Tax Implications:**  The tax implications vary significantly depending on the business structure.  Consult with a tax professional to determine the most tax-efficient structure for your specific circumstances.
#
# * **Regulatory Requirements:**  Different business structures have different regulatory requirements (e.g., filing fees, annual reports, tax filings).
#
# * **Future Growth Plans:** Consider your long-term goals.  A simpler structure might be sufficient initially, but you may need to restructure as your business grows.
#
# * **Legal and Financial Advice:**  It's crucial to seek professional legal and financial advice before making a decision.  A lawyer and a CPA can help you understand the implications of each option and choose the best structure for your needs.
#
#
# In short, while a sole proprietorship might be sufficient for a very small, low-risk startup, most tech startups will benefit from the liability protection offered by an LLC or corporation.  Consult with legal and financial professionals to determine the best structure for your specific situation.
#
#
# **Disclaimer:** This information is for general educational purposes only and should not be considered legal or financial advice.  You should consult with qualified professionals to make informed decisions regarding your business structure.
#
#
# **Resources:**
#
# * **Small Business Administration (SBA):** Offers free resources and counseling on starting and growing a business.
# * **LegalZoom:** Provides online legal services for business formation.
# * **Rocket Lawyer:** Offers online legal services for business formation and other legal needs.
# * **Your local Small Business Development Center (SBDC):** Provides free consulting and resources for small businesses.
# * **A CPA or tax professional:** Can help you understand the tax implications of different business structures.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Q: What are the tax implications of forming an LLC?
# A: What are the tax implications of forming an LLC?
#
# The tax implications of forming an LLC depend on how you elect to be taxed.  LLCs are pass-through entities, meaning profits and losses are passed through to the owners' personal income tax returns.  However, you have several options for how that taxation is structured:
#
# 1. **Disregarded Entity:**  If you're a single-member LLC (SMLLC), the IRS generally treats it as a disregarded entity. This means the LLC itself doesn't file a separate tax return.  The profits and losses are reported on the owner's personal income tax return, Schedule C (Profit or Loss from Business).
#
# 2. **Partnership:** If you have multiple members, the LLC is typically taxed as a partnership.  Each member reports their share of the profits and losses on their personal income tax return, Schedule K-1.
#
# 3. **S Corporation:**  You can elect to be taxed as an S corporation. This can offer some tax advantages, such as avoiding self-employment taxes on some of the profits. However, it comes with stricter compliance requirements.  You'll need to file Form 2553 to make the election.
#
# 4. **C Corporation:**  While less common for small businesses, you can elect to be taxed as a C corporation. This means the LLC files its own corporate tax return (Form 1120), and you pay corporate income tax on profits.  You'll also pay taxes on dividends you receive as a shareholder.  This structure is generally more complex and offers fewer tax advantages for small businesses.
#
# **In summary:**  The tax implications of forming an LLC are not automatically high taxes.  The tax burden depends heavily on how you choose to be taxed.  Consulting with a tax professional is highly recommended to determine the best tax structure for your specific situation.  They can help you weigh the advantages and disadvantages of each option.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Q: How does Delaware compare to Washington for incorporating a business?
# A: How does Delaware compare to Washington for incorporating a business?
#
# Delaware and Washington are two popular states for business incorporation, each with its own advantages. Here's a comparison:
#
# **Delaware:**
#
# * **Business-Friendly Environment:** Delaware has a long-standing reputation for being business-friendly.  It offers a predictable legal system, favorable tax laws (no corporate income tax), and a well-established court system for business disputes.
# * **Flexible Corporate Law:** Delaware's corporate laws are very flexible, allowing for customized corporate structures and governance. This is particularly attractive to larger companies and those seeking to raise capital.
# * **Anonymity:** Delaware offers a high degree of anonymity for business owners.  You don't have to disclose your name or address publicly.
# * **Easy Incorporation Process:** The process of incorporating in Delaware is relatively straightforward and efficient.
#
# **Washington:**
#
# * **Simpler Paperwork:** Washington generally has simpler incorporation paperwork than Delaware.  This can make it a more attractive option for smaller businesses or those with less legal expertise.
# * **State Taxes:** Washington has a business and occupation (B&O) tax, which is a tax on gross receipts.  This can be more straightforward than the complex tax structures in some other states, but it can also be higher for some businesses.
# * **Access to a Large Market:** Washington's location offers access to a large domestic and international market.  This is particularly beneficial for businesses involved in trade or export.
# * **Quality of Life:** Washington state is known for its high quality of life, which can be a significant factor for business owners and employees.
#
# **Which is better?**
#
# There's no definitive answer.  The best state for incorporation depends on your specific business needs, goals, and preferences.  If you prioritize a highly flexible legal framework, strong privacy protections, and a well-established business climate, Delaware is a strong contender.  If you value simplicity, access to a large market, and a good work-life balance, Washington might be a better fit.
#
# It's crucial to consult with legal and financial professionals to determine the best state for your business incorporation. They can help you weigh the pros and cons and make an informed decision based on your unique circumstances.
#
# **In short:** Delaware offers a more specialized, business-focused environment, while Washington offers a simpler process and a good balance of business and lifestyle.  Neither is inherently "better" – it's all about finding the right fit for your business.
